# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwalp111/PRAJ18-DSA/blob/ADO004/Sorting_methods/selection_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("selection sort")
# Out:
# selection sort
